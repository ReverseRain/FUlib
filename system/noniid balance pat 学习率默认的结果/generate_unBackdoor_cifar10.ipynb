# %%
# 初始化一个需要被遗忘的模型
!  python main.py -data Cifar10 -m cnn -algo FedEraser -gr 100 -did 0 -uc 1 -nc 10 -s learning
# Out:
# ...
# goal = test
# device = cuda
# device_id = 0
# dataset = Cifar10
# num_classes = 10
# model = cnn
# batch_size = 10
# local_learning_rate = 0.005
# learning_rate_decay = False
# learning_rate_decay_gamma = 0.99
# global_rounds = 100
# local_epochs = 1
# algorithm = FedEraser
# join_ratio = 1.0
# random_join_ratio = False
# num_clients = 10
# prev = 0
# times = 1
# eval_gap = 1
# save_folder_name = items
# auto_break = False
# dlg_eval = False
# dlg_gap = 100
# batch_num_per_client = 2
# num_new_clients = 0
# fine_tuning_epoch_new = 0
# feature_dim = 512
# vocab_size = 32000
# max_len = 200
# client_drop_rate = 0.0
# train_slow_rate = 0.0
# send_slow_rate = 0.0
# time_select = False
# time_threthold = 10000
# unlearning_clients = [1]
# unlearning_ground = 2
# learning_state = learning
# attack = False
# unlearning_rate = 0.0005
# ...
# CNN(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU(inplace=True)
# ...

# %%
! python main.py -data Cifar10 -m cnn -algo FedGEM -did 0 -uc 1 -nc 10 -s unlearning -ugr 10
# Out:
# ...
# goal = test
# device = cuda
# device_id = 0
# dataset = Cifar10
# num_classes = 10
# model = cnn
# batch_size = 10
# local_learning_rate = 0.005
# learning_rate_decay = False
# learning_rate_decay_gamma = 0.99
# global_rounds = 2000
# local_epochs = 1
# algorithm = FedGEM
# join_ratio = 1.0
# random_join_ratio = False
# num_clients = 10
# prev = 0
# times = 1
# eval_gap = 1
# save_folder_name = items
# auto_break = False
# dlg_eval = False
# dlg_gap = 100
# batch_num_per_client = 2
# num_new_clients = 0
# fine_tuning_epoch_new = 0
# feature_dim = 512
# vocab_size = 32000
# max_len = 200
# client_drop_rate = 0.0
# train_slow_rate = 0.0
# send_slow_rate = 0.0
# time_select = False
# time_threthold = 10000
# unlearning_clients = [1]
# unlearning_ground = 10
# learning_state = unlearning
# attack = False
# unlearning_rate = 0.0005
# ...
# CNN(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU(inplace=True)
# ...

# %%
! python main.py -data Cifar10 -m cnn -algo FedBU -did 0 -uc 1 -nc 10 -s unlearning -ugr 10
# Out:
# ...
# goal = test
# device = cuda
# device_id = 0
# dataset = Cifar10
# num_classes = 10
# model = cnn
# batch_size = 10
# local_learning_rate = 0.005
# learning_rate_decay = False
# learning_rate_decay_gamma = 0.99
# global_rounds = 2000
# local_epochs = 1
# algorithm = FedBU
# join_ratio = 1.0
# random_join_ratio = False
# num_clients = 10
# prev = 0
# times = 1
# eval_gap = 1
# save_folder_name = items
# auto_break = False
# dlg_eval = False
# dlg_gap = 100
# batch_num_per_client = 2
# num_new_clients = 0
# fine_tuning_epoch_new = 0
# feature_dim = 512
# vocab_size = 32000
# max_len = 200
# client_drop_rate = 0.0
# train_slow_rate = 0.0
# send_slow_rate = 0.0
# time_select = False
# time_threthold = 10000
# unlearning_clients = [1]
# unlearning_ground = 10
# learning_state = unlearning
# attack = False
# unlearning_rate = 0.0005
# ...
# CNN(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU(inplace=True)
# ...

# %%
! python main.py -data Cifar10 -m cnn -algo FedEE -did 0 -uc 1 -nc 10 -s unlearning -ugr 10
# Out:
# ...
# goal = test
# device = cuda
# device_id = 0
# dataset = Cifar10
# num_classes = 10
# model = cnn
# batch_size = 10
# local_learning_rate = 0.005
# learning_rate_decay = False
# learning_rate_decay_gamma = 0.99
# global_rounds = 2000
# local_epochs = 1
# algorithm = FedEE
# join_ratio = 1.0
# random_join_ratio = False
# num_clients = 10
# prev = 0
# times = 1
# eval_gap = 1
# save_folder_name = items
# auto_break = False
# dlg_eval = False
# dlg_gap = 100
# batch_num_per_client = 2
# num_new_clients = 0
# fine_tuning_epoch_new = 0
# feature_dim = 512
# vocab_size = 32000
# max_len = 200
# client_drop_rate = 0.0
# train_slow_rate = 0.0
# send_slow_rate = 0.0
# time_select = False
# time_threthold = 10000
# unlearning_clients = [1]
# unlearning_ground = 10
# learning_state = unlearning
# attack = False
# unlearning_rate = 0.0005
# ...
# CNN(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU(inplace=True)
# ...

# %%
! python main.py -data Cifar10 -m cnn -algo FedOSD -did 0 -uc 1 -nc 10 -s unlearning -ugr 10
# Out:
# ...
# goal = test
# device = cuda
# device_id = 0
# dataset = Cifar10
# num_classes = 10
# model = cnn
# batch_size = 10
# local_learning_rate = 0.005
# learning_rate_decay = False
# learning_rate_decay_gamma = 0.99
# global_rounds = 2000
# local_epochs = 1
# algorithm = FedOSD
# join_ratio = 1.0
# random_join_ratio = False
# num_clients = 10
# prev = 0
# times = 1
# eval_gap = 1
# save_folder_name = items
# auto_break = False
# dlg_eval = False
# dlg_gap = 100
# batch_num_per_client = 2
# num_new_clients = 0
# fine_tuning_epoch_new = 0
# feature_dim = 512
# vocab_size = 32000
# max_len = 200
# client_drop_rate = 0.0
# train_slow_rate = 0.0
# send_slow_rate = 0.0
# time_select = False
# time_threthold = 10000
# unlearning_clients = [1]
# unlearning_ground = 10
# learning_state = unlearning
# attack = False
# unlearning_rate = 0.0005
# ...
# CNN(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU(inplace=True)
# ...

# %%
! python main.py -data Cifar10 -m cnn -algo FedROME -did 0 -uc 1 -nc 10 -s unlearning -ugr 10
# Out:
# ...
# goal = test
# device = cuda
# device_id = 0
# dataset = Cifar10
# num_classes = 10
# model = cnn
# batch_size = 10
# local_learning_rate = 0.005
# learning_rate_decay = False
# learning_rate_decay_gamma = 0.99
# global_rounds = 2000
# local_epochs = 1
# algorithm = FedROME
# join_ratio = 1.0
# random_join_ratio = False
# num_clients = 10
# prev = 0
# times = 1
# eval_gap = 1
# save_folder_name = items
# auto_break = False
# dlg_eval = False
# dlg_gap = 100
# batch_num_per_client = 2
# num_new_clients = 0
# fine_tuning_epoch_new = 0
# feature_dim = 512
# vocab_size = 32000
# max_len = 200
# client_drop_rate = 0.0
# train_slow_rate = 0.0
# send_slow_rate = 0.0
# time_select = False
# time_threthold = 10000
# unlearning_clients = [1]
# unlearning_ground = 10
# learning_state = unlearning
# attack = False
# unlearning_rate = 0.0005
# ...
# CNN(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU(inplace=True)
# ...
