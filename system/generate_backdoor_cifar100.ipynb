# %%
# 初始化一个需要被遗忘的模型,这个已经在台式机跑了
!  python main.py -data Cifar100 -m cnn -algo FedEraser -gr 100 -did 0 -uc 1 -nc 10 -s learning -att True

# %%
! python main.py -data Cifar100 -m cnn -algo FedGEM -did 0 -uc 1 -nc 10 -s unlearning -ugr 10 -att True -ulr 0.0001

# %%
! python main.py -data Cifar100 -m cnn -algo FedBU -did 0 -uc 1 -nc 10 -s unlearning -ugr 10 -att True -ulr 0.0001

# %%
! python main.py -data Cifar100 -m cnn -algo FedEE -did 0 -uc 1 -nc 10 -s unlearning -ugr 10 -att True -ulr 0.0001

# %%
! python main.py -data Cifar100 -m cnn -algo FedOSD -did 0 -uc 1 -nc 10 -s unlearning -ugr 10 -att True -ulr 0.0001

# %%
! python main.py -data Cifar100 -m cnn -algo FedUG -did 0 -uc 1 -nc 10 -s unlearning -ugr 10 -att True -ulr 0.0001
