# %%
# 初始化一个需要被遗忘的模型
!  python main.py -data Cifar10 -m cnn -algo FedEraser -gr 30 -did 0 -uc 1 -nc 10 -s learning -att True
# Out:
# ==================================================
# goal = test
# device = cuda
# device_id = 0
# dataset = Cifar10
# num_classes = 10
# model = cnn
# batch_size = 10
# local_learning_rate = 0.005
# learning_rate_decay = False
# learning_rate_decay_gamma = 0.99
# global_rounds = 30
# local_epochs = 1
# algorithm = FedEraser
# join_ratio = 1.0
# random_join_ratio = False
# num_clients = 10
# prev = 0
# times = 1
# eval_gap = 1
# save_folder_name = items
# auto_break = False
# dlg_eval = False
# dlg_gap = 100
# batch_num_per_client = 2
# num_new_clients = 0
# fine_tuning_epoch_new = 0
# feature_dim = 512
# vocab_size = 32000
# max_len = 200
# client_drop_rate = 0.0
# train_slow_rate = 0.0
# send_slow_rate = 0.0
# time_select = False
# time_threthold = 10000
# unlearning_clients = [1]
# unlearning_ground = 2
# learning_state = learning
# attack = True
# unlearning_rate = 0.0005
# ==================================================
# CNN(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc1): Sequential(
#     (0): Linear(in_features=1600, out_features=512, bias=True)
#     (1): ReLU(inplace=True)
#   )
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# )
#
# Join ratio / total clients: 1.0 / 10
# Finished creating server and clients.
#
# ============= Training start =============
# Creating server and clients ...
#
# -------------Round number: 0-------------
#
# Evaluate global model
# Averaged Train Loss: 2.3000
# Averaged Test Accurancy: 0.1059
# Averaged Test AUC: 0.5211
# Std Test Accurancy: 0.1808
# Std Test AUC: 0.1605
# Average Attack Accurancy:0.0067
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 16.866488933563232
#
# -------------Round number: 1-------------
#
# Evaluate global model
# Averaged Train Loss: 2.6076
# Averaged Test Accurancy: 0.0564
# Averaged Test AUC: 0.5526
# Std Test Accurancy: 0.1594
# Std Test AUC: 0.1034
# Average Attack Accurancy:1.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 15.2600257396698
#
# -------------Round number: 2-------------
#
# Evaluate global model
# Averaged Train Loss: 2.7092
# Averaged Test Accurancy: 0.0564
# Averaged Test AUC: 0.5920
# Std Test Accurancy: 0.1594
# Std Test AUC: 0.0812
# Average Attack Accurancy:1.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 15.807474613189697
#
# -------------Round number: 3-------------
#
# Evaluate global model
# Averaged Train Loss: 2.5822
# Averaged Test Accurancy: 0.0564
# Averaged Test AUC: 0.6264
# Std Test Accurancy: 0.1594
# Std Test AUC: 0.0661
# Average Attack Accurancy:1.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 15.767138719558716
#
# -------------Round number: 4-------------
#
# Evaluate global model
# Averaged Train Loss: 2.4904
# Averaged Test Accurancy: 0.0564
# Averaged Test AUC: 0.6381
# Std Test Accurancy: 0.1594
# Std Test AUC: 0.0643
# Average Attack Accurancy:1.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 15.59526014328003
#
# -------------Round number: 5-------------
#
# Evaluate global model
# Averaged Train Loss: 2.4265
# Averaged Test Accurancy: 0.0627
# Averaged Test AUC: 0.6501
# Std Test Accurancy: 0.1571
# Std Test AUC: 0.0620
# Average Attack Accurancy:0.9987
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 16.83131217956543
#
# -------------Round number: 6-------------
#
# Evaluate global model
# Averaged Train Loss: 2.3872
# Averaged Test Accurancy: 0.0706
# Averaged Test AUC: 0.6623
# Std Test Accurancy: 0.1548
# Std Test AUC: 0.0590
# Average Attack Accurancy:0.9980
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 16.75313401222229
#
# -------------Round number: 7-------------
#
# Evaluate global model
# Averaged Train Loss: 2.3600
# Averaged Test Accurancy: 0.0847
# Averaged Test AUC: 0.6724
# Std Test Accurancy: 0.1519
# Std Test AUC: 0.0543
# Average Attack Accurancy:0.9913
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 16.612844467163086
#
# -------------Round number: 8-------------
#
# Evaluate global model
# Averaged Train Loss: 2.3216
# Averaged Test Accurancy: 0.0941
# Averaged Test AUC: 0.6837
# Std Test Accurancy: 0.1512
# Std Test AUC: 0.0539
# Average Attack Accurancy:0.9760
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 15.758832931518555
#
# -------------Round number: 9-------------
#
# Evaluate global model
# Averaged Train Loss: 2.2481
# Averaged Test Accurancy: 0.1123
# Averaged Test AUC: 0.6962
# Std Test Accurancy: 0.1468
# Std Test AUC: 0.0480
# Average Attack Accurancy:0.9520
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 14.96199345588684
#
# -------------Round number: 10-------------
#
# Evaluate global model
# Averaged Train Loss: 2.2173
# Averaged Test Accurancy: 0.1282
# Averaged Test AUC: 0.7041
# Std Test Accurancy: 0.1425
# Std Test AUC: 0.0468
# Average Attack Accurancy:0.9280
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 15.174258947372437
#
# -------------Round number: 11-------------
#
# Evaluate global model
# Averaged Train Loss: 2.2086
# Averaged Test Accurancy: 0.1342
# Averaged Test AUC: 0.7108
# Std Test Accurancy: 0.1428
# Std Test AUC: 0.0434
# Average Attack Accurancy:0.9293
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 14.870623111724854
#
# -------------Round number: 12-------------
#
# Evaluate global model
# Averaged Train Loss: 2.2006
# Averaged Test Accurancy: 0.1417
# Averaged Test AUC: 0.7148
# Std Test Accurancy: 0.1417
# Std Test AUC: 0.0420
# Average Attack Accurancy:0.9260
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 15.112102746963501
#
# -------------Round number: 13-------------
#
# Evaluate global model
# Averaged Train Loss: 2.1568
# Averaged Test Accurancy: 0.1616
# Averaged Test AUC: 0.7228
# Std Test Accurancy: 0.1371
# Std Test AUC: 0.0426
# Average Attack Accurancy:0.8987
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 15.213823795318604
#
# -------------Round number: 14-------------
#
# Evaluate global model
# Averaged Train Loss: 2.1426
# Averaged Test Accurancy: 0.1757
# Averaged Test AUC: 0.7284
# Std Test Accurancy: 0.1332
# Std Test AUC: 0.0405
# Average Attack Accurancy:0.8840
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 15.134547233581543
#
# -------------Round number: 15-------------
#
# Evaluate global model
# Averaged Train Loss: 2.1186
# Averaged Test Accurancy: 0.1921
# Averaged Test AUC: 0.7333
# Std Test Accurancy: 0.1339
# Std Test AUC: 0.0430
# Average Attack Accurancy:0.8733
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 15.35689902305603
#
# -------------Round number: 16-------------
#
# Evaluate global model
# Averaged Train Loss: 2.1024
# Averaged Test Accurancy: 0.2029
# Averaged Test AUC: 0.7365
# Std Test Accurancy: 0.1372
# Std Test AUC: 0.0432
# Average Attack Accurancy:0.8653
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 14.91748046875
#
# -------------Round number: 17-------------
#
# Evaluate global model
# Averaged Train Loss: 2.0952
# Averaged Test Accurancy: 0.2059
# Averaged Test AUC: 0.7391
# Std Test Accurancy: 0.1395
# Std Test AUC: 0.0411
# Average Attack Accurancy:0.8713
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 14.881285905838013
#
# -------------Round number: 18-------------
#
# Evaluate global model
# Averaged Train Loss: 2.0659
# Averaged Test Accurancy: 0.2213
# Averaged Test AUC: 0.7450
# Std Test Accurancy: 0.1333
# Std Test AUC: 0.0403
# Average Attack Accurancy:0.8527
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 15.368193626403809
#
# -------------Round number: 19-------------
#
# Evaluate global model
# Averaged Train Loss: 2.0830
# Averaged Test Accurancy: 0.2101
# Averaged Test AUC: 0.7428
# Std Test Accurancy: 0.1427
# Std Test AUC: 0.0389
# Average Attack Accurancy:0.8733
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 15.332106590270996
#
# -------------Round number: 20-------------
#
# Evaluate global model
# Averaged Train Loss: 2.0404
# Averaged Test Accurancy: 0.2339
# Averaged Test AUC: 0.7511
# Std Test Accurancy: 0.1454
# Std Test AUC: 0.0407
# Average Attack Accurancy:0.8493
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 15.008859872817993
#
# -------------Round number: 21-------------
#
# Evaluate global model
# Averaged Train Loss: 2.0511
# Averaged Test Accurancy: 0.2320
# Averaged Test AUC: 0.7521
# Std Test Accurancy: 0.1437
# Std Test AUC: 0.0416
# Average Attack Accurancy:0.8513
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 15.370994806289673
#
# -------------Round number: 22-------------
#
# Evaluate global model
# Averaged Train Loss: 2.0583
# Averaged Test Accurancy: 0.2266
# Averaged Test AUC: 0.7515
# Std Test Accurancy: 0.1424
# Std Test AUC: 0.0361
# Average Attack Accurancy:0.8620
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 15.38641619682312
#
# -------------Round number: 23-------------
#
# Evaluate global model
# Averaged Train Loss: 2.0422
# Averaged Test Accurancy: 0.2354
# Averaged Test AUC: 0.7544
# Std Test Accurancy: 0.1449
# Std Test AUC: 0.0376
# Average Attack Accurancy:0.8547
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 15.561735391616821
#
# -------------Round number: 24-------------
#
# Evaluate global model
# Averaged Train Loss: 2.0108
# Averaged Test Accurancy: 0.2496
# Averaged Test AUC: 0.7599
# Std Test Accurancy: 0.1450
# Std Test AUC: 0.0406
# Average Attack Accurancy:0.8287
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 15.567745208740234
#
# -------------Round number: 25-------------
#
# Evaluate global model
# Averaged Train Loss: 1.9986
# Averaged Test Accurancy: 0.2530
# Averaged Test AUC: 0.7630
# Std Test Accurancy: 0.1418
# Std Test AUC: 0.0348
# Average Attack Accurancy:0.8233
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 16.001312971115112
#
# -------------Round number: 26-------------
#
# Evaluate global model
# Averaged Train Loss: 2.0146
# Averaged Test Accurancy: 0.2485
# Averaged Test AUC: 0.7625
# Std Test Accurancy: 0.1437
# Std Test AUC: 0.0344
# Average Attack Accurancy:0.8367
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 16.368364334106445
#
# -------------Round number: 27-------------
#
# Evaluate global model
# Averaged Train Loss: 1.9803
# Averaged Test Accurancy: 0.2576
# Averaged Test AUC: 0.7664
# Std Test Accurancy: 0.1410
# Std Test AUC: 0.0367
# Average Attack Accurancy:0.8160
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 15.665880918502808
#
# -------------Round number: 28-------------
#
# Evaluate global model
# Averaged Train Loss: 1.9768
# Averaged Test Accurancy: 0.2595
# Averaged Test AUC: 0.7679
# Std Test Accurancy: 0.1475
# Std Test AUC: 0.0361
# Average Attack Accurancy:0.8153
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 15.173134565353394
#
# -------------Round number: 29-------------
#
# Evaluate global model
# Averaged Train Loss: 1.9768
# Averaged Test Accurancy: 0.2581
# Averaged Test AUC: 0.7684
# Std Test Accurancy: 0.1416
# Std Test AUC: 0.0341
# Average Attack Accurancy:0.8227
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 15.66777753829956
#
# -------------Round number: 30-------------
#
# Evaluate global model
# Averaged Train Loss: 1.9822
# Averaged Test Accurancy: 0.2531
# Averaged Test AUC: 0.7675
# Std Test Accurancy: 0.1436
# Std Test AUC: 0.0312
# Average Attack Accurancy:0.8307
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 15.621419429779053
#
# Best accuracy.
# 0.2594814814814815
#
# Average time cost per round.
# 15.536765964825948
# File path: ../results/Cifar10_FedEraser_test.h5
#
# Average time cost: 484.35s.
# All done!

# %%
! python main.py -data Cifar10 -m cnn -algo FedGEM -did 0 -uc 1 -nc 10 -s unlearning -ugr 10 -att True -ulr 0.0001
# Out:
# ==================================================
# goal = test
# device = cuda
# device_id = 0
# dataset = Cifar10
# num_classes = 10
# model = cnn
# batch_size = 10
# local_learning_rate = 0.005
# learning_rate_decay = False
# learning_rate_decay_gamma = 0.99
# global_rounds = 2000
# local_epochs = 1
# algorithm = FedGEM
# join_ratio = 1.0
# random_join_ratio = False
# num_clients = 10
# prev = 0
# times = 1
# eval_gap = 1
# save_folder_name = items
# auto_break = False
# dlg_eval = False
# dlg_gap = 100
# batch_num_per_client = 2
# num_new_clients = 0
# fine_tuning_epoch_new = 0
# feature_dim = 512
# vocab_size = 32000
# max_len = 200
# client_drop_rate = 0.0
# train_slow_rate = 0.0
# send_slow_rate = 0.0
# time_select = False
# time_threthold = 10000
# unlearning_clients = [1]
# unlearning_ground = 10
# learning_state = unlearning
# attack = True
# unlearning_rate = 0.0001
# ==================================================
# CNN(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc1): Sequential(
#     (0): Linear(in_features=1600, out_features=512, bias=True)
#     (1): ReLU(inplace=True)
#   )
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# )
#
# Join ratio / total clients: 1.0 / 10
# Finished creating server and clients.
#
# ============= Unlearning start =============
#
# -------------Round number: 0-------------
#
# Evaluate global model
# Averaged Train Loss: 1.9523
# Averaged Test Accurancy: 0.2651
# Averaged Test AUC: 0.7725
# Std Test Accurancy: 0.1494
# Std Test AUC: 0.0381
# Average Attack Accurancy:0.8067
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 17.097381114959717
#
# -------------Round number: 1-------------
#
# Evaluate global model
# Averaged Train Loss: 1.7888
# Averaged Test Accurancy: 0.3981
# Averaged Test AUC: 0.7911
# Std Test Accurancy: 0.2012
# Std Test AUC: 0.1569
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 15.764541149139404
#
# -------------Round number: 2-------------
#
# Evaluate global model
# Averaged Train Loss: 1.8097
# Averaged Test Accurancy: 0.3796
# Averaged Test AUC: 0.7872
# Std Test Accurancy: 0.1542
# Std Test AUC: 0.1526
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 15.943836212158203
#
# -------------Round number: 3-------------
#
# Evaluate global model
# Averaged Train Loss: 1.8523
# Averaged Test Accurancy: 0.3465
# Averaged Test AUC: 0.7787
# Std Test Accurancy: 0.1568
# Std Test AUC: 0.1535
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 16.085867166519165
#
# -------------Round number: 4-------------
#
# Evaluate global model
# Averaged Train Loss: 1.8797
# Averaged Test Accurancy: 0.3206
# Averaged Test AUC: 0.7738
# Std Test Accurancy: 0.1764
# Std Test AUC: 0.1532
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 16.22030735015869
#
# -------------Round number: 5-------------
#
# Evaluate global model
# Averaged Train Loss: 1.9025
# Averaged Test Accurancy: 0.3011
# Averaged Test AUC: 0.7704
# Std Test Accurancy: 0.1948
# Std Test AUC: 0.1542
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 16.487873792648315
#
# -------------Round number: 6-------------
#
# Evaluate global model
# Averaged Train Loss: 1.9166
# Averaged Test Accurancy: 0.2938
# Averaged Test AUC: 0.7682
# Std Test Accurancy: 0.2064
# Std Test AUC: 0.1556
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 15.858437299728394
#
# -------------Round number: 7-------------
#
# Evaluate global model
# Averaged Train Loss: 1.9224
# Averaged Test Accurancy: 0.2848
# Averaged Test AUC: 0.7689
# Std Test Accurancy: 0.2215
# Std Test AUC: 0.1538
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 16.297150135040283
#
# -------------Round number: 8-------------
#
# Evaluate global model
# Averaged Train Loss: 1.9195
# Averaged Test Accurancy: 0.2863
# Averaged Test AUC: 0.7699
# Std Test Accurancy: 0.2224
# Std Test AUC: 0.1529
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 16.22260570526123
#
# -------------Round number: 9-------------
#
# Evaluate global model
# Averaged Train Loss: 1.9174
# Averaged Test Accurancy: 0.2841
# Averaged Test AUC: 0.7711
# Std Test Accurancy: 0.2252
# Std Test AUC: 0.1514
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 16.13524317741394
#
# -------------Round number: 10-------------
#
# Evaluate global model
# Averaged Train Loss: 1.9282
# Averaged Test Accurancy: 0.2796
# Averaged Test AUC: 0.7695
# Std Test Accurancy: 0.2301
# Std Test AUC: 0.1531
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 15.99327540397644
# MIA Attacker to old model precision = 0.9797
# MIA Attacker to old model recall = 0.9911
# MIA Attacker to unlearning model precision = 0.7836
# MIA Attacker to unlearning model recall = 0.8861
# All done!

# %%
! python main.py -data Cifar10 -m cnn -algo FedBU -did 0 -uc 1 -nc 10 -s unlearning -ugr 10 -att True -ulr 0.0001
# Out:
# ==================================================
# goal = test
# device = cuda
# device_id = 0
# dataset = Cifar10
# num_classes = 10
# model = cnn
# batch_size = 10
# local_learning_rate = 0.005
# learning_rate_decay = False
# learning_rate_decay_gamma = 0.99
# global_rounds = 2000
# local_epochs = 1
# algorithm = FedBU
# join_ratio = 1.0
# random_join_ratio = False
# num_clients = 10
# prev = 0
# times = 1
# eval_gap = 1
# save_folder_name = items
# auto_break = False
# dlg_eval = False
# dlg_gap = 100
# batch_num_per_client = 2
# num_new_clients = 0
# fine_tuning_epoch_new = 0
# feature_dim = 512
# vocab_size = 32000
# max_len = 200
# client_drop_rate = 0.0
# train_slow_rate = 0.0
# send_slow_rate = 0.0
# time_select = False
# time_threthold = 10000
# unlearning_clients = [1]
# unlearning_ground = 10
# learning_state = unlearning
# attack = True
# unlearning_rate = 0.0001
# ==================================================
# CNN(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc1): Sequential(
#     (0): Linear(in_features=1600, out_features=512, bias=True)
#     (1): ReLU(inplace=True)
#   )
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# )
#
# Join ratio / total clients: 1.0 / 10
# Finished creating server and clients.
#
# ============= Unlearning start =============
#
# -------------Round number: 0-------------
#
# Evaluate global model
# Averaged Train Loss: 1.9523
# Averaged Test Accurancy: 0.2651
# Averaged Test AUC: 0.7725
# Std Test Accurancy: 0.1494
# Std Test AUC: 0.0381
# Average Attack Accurancy:0.8067
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 9.486268758773804
#
# -------------Round number: 1-------------
#
# Evaluate global model
# Averaged Train Loss: 3.3455
# Averaged Test Accurancy: 0.0858
# Averaged Test AUC: 0.6590
# Std Test Accurancy: 0.1434
# Std Test AUC: 0.0715
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 9.160002946853638
#
# -------------Round number: 2-------------
#
# Evaluate global model
# Averaged Train Loss: 12.6571
# Averaged Test Accurancy: 0.0547
# Averaged Test AUC: 0.5960
# Std Test Accurancy: 0.1548
# Std Test AUC: 0.0437
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 10.25260043144226
#
# -------------Round number: 3-------------
#
# Evaluate global model
# Averaged Train Loss: 32.9154
# Averaged Test Accurancy: 0.0547
# Averaged Test AUC: 0.5674
# Std Test Accurancy: 0.1548
# Std Test AUC: 0.0327
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 9.723043441772461
#
# -------------Round number: 4-------------
#
# Evaluate global model
# Averaged Train Loss: 70.6446
# Averaged Test Accurancy: 0.0547
# Averaged Test AUC: 0.5510
# Std Test Accurancy: 0.1548
# Std Test AUC: 0.0301
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 9.37760043144226
#
# -------------Round number: 5-------------
#
# Evaluate global model
# Averaged Train Loss: 134.1595
# Averaged Test Accurancy: 0.0547
# Averaged Test AUC: 0.5411
# Std Test Accurancy: 0.1548
# Std Test AUC: 0.0305
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 9.306639194488525
#
# -------------Round number: 6-------------
#
# Evaluate global model
# Averaged Train Loss: 234.7062
# Averaged Test Accurancy: 0.0547
# Averaged Test AUC: 0.5350
# Std Test Accurancy: 0.1548
# Std Test AUC: 0.0315
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 9.096091270446777
#
# -------------Round number: 7-------------
#
# Evaluate global model
# Averaged Train Loss: 385.9443
# Averaged Test Accurancy: 0.0547
# Averaged Test AUC: 0.5311
# Std Test Accurancy: 0.1548
# Std Test AUC: 0.0325
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 9.14192247390747
#
# -------------Round number: 8-------------
#
# Evaluate global model
# Averaged Train Loss: 602.4562
# Averaged Test Accurancy: 0.0547
# Averaged Test AUC: 0.5284
# Std Test Accurancy: 0.1548
# Std Test AUC: 0.0331
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 9.105282545089722
#
# -------------Round number: 9-------------
#
# Evaluate global model
# Averaged Train Loss: 902.3400
# Averaged Test Accurancy: 0.0547
# Averaged Test AUC: 0.5265
# Std Test Accurancy: 0.1548
# Std Test AUC: 0.0336
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 9.219193935394287
#
# -------------Round number: 10-------------
#
# Evaluate global model
# Averaged Train Loss: 1300.7260
# Averaged Test Accurancy: 0.0547
# Averaged Test AUC: 0.5251
# Std Test Accurancy: 0.1548
# Std Test AUC: 0.0339
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 9.419646978378296
# MIA Attacker to old model precision = 0.9908
# MIA Attacker to old model recall = 1.0000
# MIA Attacker to unlearning model precision = 0.9000
# MIA Attacker to unlearning model recall = 1.0000
# All done!

# %%
! python main.py -data Cifar10 -m cnn -algo FedEE -did 0 -uc 1 -nc 10 -s unlearning -ugr 10 -att True -ulr 0.0001
# Out:
# ==================================================
# goal = test
# device = cuda
# device_id = 0
# dataset = Cifar10
# num_classes = 10
# model = cnn
# batch_size = 10
# local_learning_rate = 0.005
# learning_rate_decay = False
# learning_rate_decay_gamma = 0.99
# global_rounds = 2000
# local_epochs = 1
# algorithm = FedEE
# join_ratio = 1.0
# random_join_ratio = False
# num_clients = 10
# prev = 0
# times = 1
# eval_gap = 1
# save_folder_name = items
# auto_break = False
# dlg_eval = False
# dlg_gap = 100
# batch_num_per_client = 2
# num_new_clients = 0
# fine_tuning_epoch_new = 0
# feature_dim = 512
# vocab_size = 32000
# max_len = 200
# client_drop_rate = 0.0
# train_slow_rate = 0.0
# send_slow_rate = 0.0
# time_select = False
# time_threthold = 10000
# unlearning_clients = [1]
# unlearning_ground = 10
# learning_state = unlearning
# attack = True
# unlearning_rate = 0.0001
# ==================================================
# CNN(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc1): Sequential(
#     (0): Linear(in_features=1600, out_features=512, bias=True)
#     (1): ReLU(inplace=True)
#   )
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# )
#
# Join ratio / total clients: 1.0 / 10
# Finished creating server and clients.
#
# ============= Unlearning start =============
#
# -------------Round number: 0-------------
#
# Evaluate global model
# Averaged Train Loss: 20.8580
# Averaged Test Accurancy: 0.1141
# Averaged Test AUC: 0.5532
# Std Test Accurancy: 0.2134
# Std Test AUC: 0.1848
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 9.649420738220215
#
# -------------Round number: 1-------------
#
# Evaluate global model
# Averaged Train Loss: 77.6831
# Averaged Test Accurancy: 0.1141
# Averaged Test AUC: 0.5526
# Std Test Accurancy: 0.2134
# Std Test AUC: 0.1944
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 9.181890487670898
#
# -------------Round number: 2-------------
#
# Evaluate global model
# Averaged Train Loss: 202.9191
# Averaged Test Accurancy: 0.1141
# Averaged Test AUC: 0.5522
# Std Test Accurancy: 0.2134
# Std Test AUC: 0.2019
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 9.768999576568604
#
# -------------Round number: 3-------------
#
# Evaluate global model
# Averaged Train Loss: 435.1154
# Averaged Test Accurancy: 0.1141
# Averaged Test AUC: 0.5517
# Std Test Accurancy: 0.2134
# Std Test AUC: 0.2058
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 9.533461809158325
#
# -------------Round number: 4-------------
#
# Evaluate global model
# Averaged Train Loss: 821.3939
# Averaged Test Accurancy: 0.1141
# Averaged Test AUC: 0.5514
# Std Test Accurancy: 0.2134
# Std Test AUC: 0.2080
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 9.76612401008606
#
# -------------Round number: 5-------------
#
# Evaluate global model
# Averaged Train Loss: 1416.3846
# Averaged Test Accurancy: 0.1141
# Averaged Test AUC: 0.5512
# Std Test Accurancy: 0.2134
# Std Test AUC: 0.2094
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 9.617403268814087
#
# -------------Round number: 6-------------
#
# Evaluate global model
# Averaged Train Loss: 2283.1395
# Averaged Test Accurancy: 0.1141
# Averaged Test AUC: 0.5511
# Std Test Accurancy: 0.2134
# Std Test AUC: 0.2104
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 9.13436770439148
#
# -------------Round number: 7-------------
#
# Evaluate global model
# Averaged Train Loss: 3493.7607
# Averaged Test Accurancy: 0.1141
# Averaged Test AUC: 0.5512
# Std Test Accurancy: 0.2134
# Std Test AUC: 0.2112
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 9.740939140319824
#
# -------------Round number: 8-------------
#
# Evaluate global model
# Averaged Train Loss: 5128.0598
# Averaged Test Accurancy: 0.1141
# Averaged Test AUC: 0.5512
# Std Test Accurancy: 0.2134
# Std Test AUC: 0.2118
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 10.237290620803833
#
# -------------Round number: 9-------------
#
# Evaluate global model
# Averaged Train Loss: 7274.8985
# Averaged Test Accurancy: 0.1141
# Averaged Test AUC: 0.5513
# Std Test Accurancy: 0.2134
# Std Test AUC: 0.2123
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 10.211480855941772
#
# -------------Round number: 10-------------
#
# Evaluate global model
# Averaged Train Loss: 10028.5837
# Averaged Test Accurancy: 0.1141
# Averaged Test AUC: 0.5514
# Std Test Accurancy: 0.2134
# Std Test AUC: 0.2127
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 10.604743003845215
# MIA Attacker to old model precision = 0.9893
# MIA Attacker to old model recall = 0.9998
# MIA Attacker to unlearning model precision = 0.9000
# MIA Attacker to unlearning model recall = 1.0000
# All done!

# %%
! python main.py -data Cifar10 -m cnn -algo FedOSD -did 0 -uc 1 -nc 10 -s unlearning -ugr 10 -att True -ulr 0.0001
# Out:
# ==================================================
# goal = test
# device = cuda
# device_id = 0
# dataset = Cifar10
# num_classes = 10
# model = cnn
# batch_size = 10
# local_learning_rate = 0.005
# learning_rate_decay = False
# learning_rate_decay_gamma = 0.99
# global_rounds = 2000
# local_epochs = 1
# algorithm = FedOSD
# join_ratio = 1.0
# random_join_ratio = False
# num_clients = 10
# prev = 0
# times = 1
# eval_gap = 1
# save_folder_name = items
# auto_break = False
# dlg_eval = False
# dlg_gap = 100
# batch_num_per_client = 2
# num_new_clients = 0
# fine_tuning_epoch_new = 0
# feature_dim = 512
# vocab_size = 32000
# max_len = 200
# client_drop_rate = 0.0
# train_slow_rate = 0.0
# send_slow_rate = 0.0
# time_select = False
# time_threthold = 10000
# unlearning_clients = [1]
# unlearning_ground = 10
# learning_state = unlearning
# attack = True
# unlearning_rate = 0.0001
# ==================================================
# CNN(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc1): Sequential(
#     (0): Linear(in_features=1600, out_features=512, bias=True)
#     (1): ReLU(inplace=True)
#   )
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# )
#
# Join ratio / total clients: 1.0 / 10
# Finished creating server and clients.
#
# ============= Unlearning start =============
#
# -------------Round number: 0-------------
#
# Evaluate global model
# Averaged Train Loss: 1.9523
# Averaged Test Accurancy: 0.2651
# Averaged Test AUC: 0.7725
# Std Test Accurancy: 0.1494
# Std Test AUC: 0.0381
# Average Attack Accurancy:0.8067
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 19.180887699127197
#
# -------------Round number: 1-------------
#
# Evaluate global model
# Averaged Train Loss: 1.7114
# Averaged Test Accurancy: 0.3962
# Averaged Test AUC: 0.8084
# Std Test Accurancy: 0.2221
# Std Test AUC: 0.0620
# Average Attack Accurancy:0.0287
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 19.538671493530273
#
# -------------Round number: 2-------------
#
# Evaluate global model
# Averaged Train Loss: 1.7512
# Averaged Test Accurancy: 0.3940
# Averaged Test AUC: 0.8012
# Std Test Accurancy: 0.2386
# Std Test AUC: 0.1112
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 17.076034545898438
#
# -------------Round number: 3-------------
#
# Evaluate global model
# Averaged Train Loss: 1.7891
# Averaged Test Accurancy: 0.3937
# Averaged Test AUC: 0.7926
# Std Test Accurancy: 0.2408
# Std Test AUC: 0.1361
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 20.69958782196045
#
# -------------Round number: 4-------------
#
# Evaluate global model
# Averaged Train Loss: 1.8150
# Averaged Test Accurancy: 0.3924
# Averaged Test AUC: 0.7877
# Std Test Accurancy: 0.2434
# Std Test AUC: 0.1490
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 19.60986638069153
#
# -------------Round number: 5-------------
#
# Evaluate global model
# Averaged Train Loss: 1.8313
# Averaged Test Accurancy: 0.3915
# Averaged Test AUC: 0.7852
# Std Test Accurancy: 0.2436
# Std Test AUC: 0.1553
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 21.27290368080139
#
# -------------Round number: 6-------------
#
# Evaluate global model
# Averaged Train Loss: 1.8449
# Averaged Test Accurancy: 0.3913
# Averaged Test AUC: 0.7834
# Std Test Accurancy: 0.2447
# Std Test AUC: 0.1598
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 18.90346121788025
#
# -------------Round number: 7-------------
#
# Evaluate global model
# Averaged Train Loss: 1.8561
# Averaged Test Accurancy: 0.3912
# Averaged Test AUC: 0.7820
# Std Test Accurancy: 0.2445
# Std Test AUC: 0.1629
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 17.028172731399536
#
# -------------Round number: 8-------------
#
# Evaluate global model
# Averaged Train Loss: 1.8655
# Averaged Test Accurancy: 0.3913
# Averaged Test AUC: 0.7810
# Std Test Accurancy: 0.2451
# Std Test AUC: 0.1653
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 17.30733060836792
#
# -------------Round number: 9-------------
#
# Evaluate global model
# Averaged Train Loss: 1.8741
# Averaged Test Accurancy: 0.3912
# Averaged Test AUC: 0.7802
# Std Test Accurancy: 0.2453
# Std Test AUC: 0.1671
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 17.543014764785767
#
# -------------Round number: 10-------------
#
# Evaluate global model
# Averaged Train Loss: 1.8812
# Averaged Test Accurancy: 0.3909
# Averaged Test AUC: 0.7795
# Std Test Accurancy: 0.2458
# Std Test AUC: 0.1684
# Average Attack Accurancy:0.0000
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 23.113888025283813
# MIA Attacker to old model precision = 0.9905
# MIA Attacker to old model recall = 1.0000
# MIA Attacker to unlearning model precision = 0.9011
# MIA Attacker to unlearning model recall = 0.8591
# All done!

# %%
! python main.py -data Cifar10 -m cnn -algo FedROME -did 0 -uc 1 -nc 10 -s unlearning -ugr 10 -att True -ulr 0.0001
# Out:
# ==================================================
# goal = test
# device = cuda
# device_id = 0
# dataset = Cifar10
# num_classes = 10
# model = cnn
# batch_size = 10
# local_learning_rate = 0.005
# learning_rate_decay = False
# learning_rate_decay_gamma = 0.99
# global_rounds = 2000
# local_epochs = 1
# algorithm = FedROME
# join_ratio = 1.0
# random_join_ratio = False
# num_clients = 10
# prev = 0
# times = 1
# eval_gap = 1
# save_folder_name = items
# auto_break = False
# dlg_eval = False
# dlg_gap = 100
# batch_num_per_client = 2
# num_new_clients = 0
# fine_tuning_epoch_new = 0
# feature_dim = 512
# vocab_size = 32000
# max_len = 200
# client_drop_rate = 0.0
# train_slow_rate = 0.0
# send_slow_rate = 0.0
# time_select = False
# time_threthold = 10000
# unlearning_clients = [1]
# unlearning_ground = 10
# learning_state = unlearning
# attack = True
# unlearning_rate = 0.0001
# ==================================================
# CNN(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc1): Sequential(
#     (0): Linear(in_features=1600, out_features=512, bias=True)
#     (1): ReLU(inplace=True)
#   )
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# )
#
# Join ratio / total clients: 1.0 / 10
# Finished creating server and clients.
#
# ============= Unlearning start =============
#
# -------------Round number: 0-------------
#
# Evaluate global model
# Averaged Train Loss: 1.9523
# Averaged Test Accurancy: 0.2651
# Averaged Test AUC: 0.7725
# Std Test Accurancy: 0.1494
# Std Test AUC: 0.0381
# Average Attack Accurancy:0.8067
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 8.111364126205444
#
# -------------Round number: 1-------------
#
# Evaluate global model
# Averaged Train Loss: 1.8907
# Averaged Test Accurancy: 0.2667
# Averaged Test AUC: 0.7715
# Std Test Accurancy: 0.1500
# Std Test AUC: 0.0343
# Average Attack Accurancy:0.8127
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 7.6480162143707275
#
# -------------Round number: 2-------------
#
# Evaluate global model
# Averaged Train Loss: 1.8669
# Averaged Test Accurancy: 0.2801
# Averaged Test AUC: 0.7712
# Std Test Accurancy: 0.1355
# Std Test AUC: 0.0322
# Average Attack Accurancy:0.7720
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 7.539927244186401
#
# -------------Round number: 3-------------
#
# Evaluate global model
# Averaged Train Loss: 1.8651
# Averaged Test Accurancy: 0.2907
# Averaged Test AUC: 0.7700
# Std Test Accurancy: 0.1156
# Std Test AUC: 0.0326
# Average Attack Accurancy:0.7060
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 8.39813756942749
#
# -------------Round number: 4-------------
#
# Evaluate global model
# Averaged Train Loss: 1.8724
# Averaged Test Accurancy: 0.2999
# Averaged Test AUC: 0.7683
# Std Test Accurancy: 0.1035
# Std Test AUC: 0.0353
# Average Attack Accurancy:0.6460
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 10.480320692062378
#
# -------------Round number: 5-------------
#
# Evaluate global model
# Averaged Train Loss: 1.8832
# Averaged Test Accurancy: 0.3069
# Averaged Test AUC: 0.7664
# Std Test Accurancy: 0.0968
# Std Test AUC: 0.0394
# Average Attack Accurancy:0.5847
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 9.727246046066284
#
# -------------Round number: 6-------------
#
# Evaluate global model
# Averaged Train Loss: 1.8990
# Averaged Test Accurancy: 0.3074
# Averaged Test AUC: 0.7631
# Std Test Accurancy: 0.0930
# Std Test AUC: 0.0428
# Average Attack Accurancy:0.5347
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 7.544910669326782
#
# -------------Round number: 7-------------
#
# Evaluate global model
# Averaged Train Loss: 1.9137
# Averaged Test Accurancy: 0.3093
# Averaged Test AUC: 0.7601
# Std Test Accurancy: 0.0926
# Std Test AUC: 0.0478
# Average Attack Accurancy:0.4780
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 7.127034425735474
#
# -------------Round number: 8-------------
#
# Evaluate global model
# Averaged Train Loss: 1.9300
# Averaged Test Accurancy: 0.3110
# Averaged Test AUC: 0.7565
# Std Test Accurancy: 0.0929
# Std Test AUC: 0.0525
# Average Attack Accurancy:0.4460
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 7.2354114055633545
#
# -------------Round number: 9-------------
#
# Evaluate global model
# Averaged Train Loss: 1.9451
# Averaged Test Accurancy: 0.3115
# Averaged Test AUC: 0.7531
# Std Test Accurancy: 0.0909
# Std Test AUC: 0.0561
# Average Attack Accurancy:0.4147
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 7.19652533531189
#
# -------------Round number: 10-------------
#
# Evaluate global model
# Averaged Train Loss: 1.9614
# Averaged Test Accurancy: 0.3075
# Averaged Test AUC: 0.7487
# Std Test Accurancy: 0.0898
# Std Test AUC: 0.0601
# Average Attack Accurancy:0.3900
# save model weights:
# save model weights: OK
# ------------------------- time cost ------------------------- 7.14675235748291
# MIA Attacker to old model precision = 0.9880
# MIA Attacker to old model recall = 1.0000
# MIA Attacker to unlearning model precision = 0.9009
# MIA Attacker to unlearning model recall = 0.8591
# All done!
